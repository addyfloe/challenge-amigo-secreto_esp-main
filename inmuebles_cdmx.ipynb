# %% [markdown]
# <a href="https://colab.research.google.com/github/addyfloe/challenge-amigo-secreto_esp-main/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
#
# La biblioteca Pandas es una de las herramientas más utilizadas por los científicos de datos para el análisis y manipulación de datos. Proporciona dos estructuras de datos principales, el DataFrame y la Serie, que se utilizan ampliamente para representar y manipular datos tabulares en Python.
#
# ¿Cuáles de las siguientes opciones presentan las definiciones correctas de las estructuras de datos DataFrame y Serie?
#
# La **Serie** es una estructura de datos unidimensional que puede almacenar cualquier tipo de datos, etiquetados con índices. Una Serie es básicamente una matriz unidimensional etiquetada que puede almacenar cualquier tipo de datos. Cada elemento de la Serie está etiquetado con un índice que se puede utilizar para acceder y manipular sus valores.
#
# El **DataFrame** es una tabla de datos bidimensional, similar a una hoja de cálculo de Excel, con columnas etiquetadas y filas numeradas. Un DataFrame es básicamente una estructura de datos bidimensional que se utiliza para almacenar información estructurada en forma de tabla.

# %% [markdown]
# ## Importando la base de datos

# %%
import pandas as pd

url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %% [markdown]
# Nos devuelve algo parecido a una tabla, sin embargo, no quedó bien definida. ¿Por qué? Porque cuando hablamos de archivos CSV, la sigla CSV significa "valores separados por coma" y este no es el caso. En este caso, los valores están separados por punto y coma. Entonces, especificamos eso en el parámetro sep de la función pd.read_csv.

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %% [markdown]
# Podemos visualizar nuestros datos simplemente escribiendo datos. Sin embargo, hay una forma más interesante de visualizar nuestros datos y es a través de un método de pandas que se llama head. datos.head() nos devuelve las primeras cinco filas de nuestro dataset.

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %% [markdown]
#  Análogamente, podemos ver las últimas cinco filas de nuestro dataset con datos.tail()

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %% [markdown]
#  Si queremos ver las primeras 10 filas, decimos datos.head(10).

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %% [markdown]
# Si queremos una muestra aleatoria de 10 filas, usamos el método datos.sample(10)

# %%
datos.sample(10)
# Out:
#                              Tipo               Colonia  Habitaciones  \
# 20548                Tienda/Salón             Nativitas             0
# 20822                Departamento              Coyoacán             3
# 7446                 Departamento               Condesa             2
# 185                  Departamento       Villa de Cortés             1
# 18107                Departamento              Santa Fe             4
# 10084                Departamento              Santa Fe             2
# 23654                Departamento  Lomas de Chapultepec             4
# 21119                Departamento              Santa Fe             2
# 10531                Departamento               Condesa             1
# 23247  Tienda en Centro Comercial              Santa Fe             0
#
#        Garages  Suites  Area     Valor  Condominio  Impuesto
# 20548        0       0   169   33075.0         NaN   16341.5
# 20822        2       1   150   22050.0      7700.0    1732.5
# ...

# %% [markdown]
# Finalmente, antes de concluir con esta primera parte del vídeo, vamos a ver qué tipo de dato es datos. Al instanciar un objeto pandas, creamos un DataFrame de pandas. Este DataFrame es una estructura de datos que es como una especie de tabla y nos permite visualizar fácilmente nuestros datos, manipularlos y hacer una serie de operaciones en nuestros datos.

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Pandas ofrece diversas funciones para importar y exportar datos en diferentes formatos. Las principales funciones de Pandas para importar datos son las siguientes:
#
# **read_csv():** Esta función se utiliza para leer archivos CSV (Comma Separated Values), que son archivos de texto que contienen datos separados por comas. Es posible proporcionar varios parámetros para personalizar la lectura del CSV, como el delimitador, el encabezado, el tipo de codificación, entre otros.
#
# **read_excel():** Esta función se utiliza para leer archivos de Excel (.xls o .xlsx) y crear un DataFrame a partir de los datos.
#
# **read_json():** Esta función se utiliza para leer archivos JSON (JavaScript Object Notation), que son archivos de texto que contienen datos en formato de objeto JavaScript.
#
# **read_html():** Esta función se utiliza para leer tablas HTML, que son estructuras de datos organizadas en formato de tabla en una página web.
#
# **read_sql():** Esta función se utiliza para leer datos de una base de datos relacional, como MySQL, PostgreSQL y SQL Server. Pandas es capaz de importar datos de diferentes maneras, lo que permite ajustar parámetros como la consulta, el nombre de la tabla y el tipo de datos de las columnas.

# %% [markdown]
# # **Exploracion inicial de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 20476                   Rancho       Las Águilas             8        0
# 8951              Departamento          Coyoacán             2        0
# 22285  Conjunto Comercial/Sala          Narvarte             0        0
# 14141  Conjunto Comercial/Sala  Centro Histórico             0        0
# 8517   Conjunto Comercial/Sala          Coyoacán             0        0
#
#        Suites   Area    Valor  Condominio  Impuesto
# 20476       7  32000  52500.0         NaN       NaN
# 8951        1     75  15750.0      3500.0    5950.0
# 22285       0     79  10500.0      2835.0     875.0
# 14141       0     92   6300.0      2611.0     801.5
# 8517        0     30   6650.0      3500.0     301.0

# %% [markdown]
# Lo primero que siempre debes hacer cuando recibes un dataset es conocer su tamaño. Para ello, utilizamos el atributo shape. Entonces, le das shape y te mostrará, en la primera posición de la tupla, la cantidad de filas y en la segunda posición, la cantidad de columnas. Entonces, tenemos veinticinco mil ciento veintiún filas por nueve columnas.

# %%
datos.shape
# Out:
# (25121, 9)

# %% [markdown]
# Entonces, datos.shape ya me da la forma de mi dataset. De la misma manera, si quiero saber cuáles son las columnas, lo que hago es datos.columns. Me devuelve un objeto de tipo Pandas Index que tiene las columnas, es parecido a un array. Entonces, tiene tipo, colonia, habitaciones, garajes, suites, área, valor, condominio e impuesto. Aquí están nuestras nueve columnas del dataset.

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %% [markdown]
# Adicionalmente, puedo querer saber de forma resumida qué es lo que hay en mi conjunto de datos. Entonces, le doy datos.info(), que es un método, y me dice que se trata de un dataframe Pandas que tiene las siguientes entradas de 0 a 25.120, por eso son 25.121 filas y tiene un total de 9 columnas, como ya sabíamos. Aquí las enumera: la columna 0 es tipo, tiene 25.121 elementos que no son nulos y el tipo, el dtype. Tenemos tipo objeto, tenemos tipo int64 y tenemos float64.

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# Es interesante porque aquí tenemos un resumen de todos nuestros datos. Por ejemplo, ya sé que si tengo un total de 25.121 entradas, lo ideal es que todas mis columnas tengan el mismo valor, pero aquí ya empiezo a notar que algunas columnas no tienen ese mismo valor. Más adelante vamos a ver qué podemos hacer en este punto.
#
# También es una buena práctica saber qué es lo que contiene cada una de estas columnas. Porque, ¿qué es tipo objeto? ¿Qué es tipo int64? ¿Qué es tipo float? Entonces, voy a tomar una de cada una. Por ejemplo, voy a tomar la columna tipo. ¿Cómo lo hago? Hago datos['tipo']. Cuando hablo de comillas, pueden ser comillas sencillas o comillas dobles. Me devuelve una serie Pandas, que se diferencia de un dataframe porque lo único que tiene es un índice y la información contenida. Es un Pandas y me dice dtype objeto y cuando lo observo, veo que todo esto son strings, son cadenas de caracteres, es texto.

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %% [markdown]
# Si quiero saber, por ejemplo, esta columna habitaciones, puedo hacerlo de la siguiente forma: datos['habitaciones', 'valor']. Nota que coloqué dos corchetes porque estoy pasando dentro como parámetro una lista con mis dos columnas. De esta manera, ya no me devuelve más una serie Pandas, sino que ya me devuelve un dataframe. Veo que habitaciones son números enteros y valor son números decimales. Entonces, ya sé que int quiere decir número entero y float quiere decir número decimal. Lógicamente, son temas que seguramente si ya has estado trabajando con programación, lo tienes muy claro, pero tal vez hay alguna persona que está conociendo la biblioteca, que está aprendiendo a programar, entonces por eso es importante hacer esa claridad y esa especificación.

# %%
datos[['Habitaciones', 'Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# Importar la biblioteca Pandas;
# Realizar la lectura de archivos csv;
# Identificar un DataFrame;
# Visualizar las primeras y últimas filas de un DataFrame;
# Verificar la cantidad de filas y columnas de un DataFrame;
# Comprobar los tipos de datos de cada columna de un DataFrame;
# Seleccionar una o varias columnas.
